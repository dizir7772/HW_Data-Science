# %% [markdown]
# <a href="https://colab.research.google.com/github/PIRomanCod/DataSciense_HW/blob/main/Hw2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Проведіть аналіз файлу 2017_jun_final.csv. Файл містить результати опитування розробників у червні 2017 року.**

# %% [markdown]
# - Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import pandas as pd

coders = pd.read_csv("/content/2017_jun_final - 2017_jun_final.csv")

# %% [markdown]
# - Прочитайте отриману таблицю, використовуючи метод head

# %%
coders.head()
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %% [markdown]
# - Визначте розмір таблиці за допомогою методу shape

# %%
coders.shape
# Out:
# (8704, 25)

# %% [markdown]
# - Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
coders.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# - Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
#Кількість пропусків
res1 = coders.isnull().sum()
print("Кількість пропусків")
print(res1)
#Частка пропусків
res2 = coders.isna().mean()
print("\nЧастка пропусків")
print(res2)
# Out:
# Кількість пропусків
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Спеціалізація                       7219
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Університет                          358
# Ще студент                             0
# Рівень англійської                     0
# Предметна область                    223
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# ...

# %% [markdown]
# - Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
keep_columns = ['Мова програмування'] + list(coders.dropna(axis=1, how='any').columns)
coders = coders[keep_columns]
coders
# Out:
#      Мова програмування     N                    Посада  \
# 0                   NaN     1        Junior QA engineer
# 1                   NaN     2        Junior QA engineer
# 2               C#/.NET     3         Software Engineer
# 3            JavaScript     4         Software Engineer
# 4            JavaScript     5  Senior Software Engineer
# ...                 ...   ...                       ...
# 8699                NaN  8700               QA engineer
# 8700                NaN  8701                 Marketing
# 8701         Ruby/Rails  8702  Junior Software Engineer
# 8702                NaN  8703                 Team lead
# 8703               Java  8704  Senior Software Engineer
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                        0.5                              0.5
# 1            менше 3 місяців                  менше 3 місяців
# 2                          4                                1
# ...

# %% [markdown]
# - Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
#Частка пропусків
res2 = coders.isna().mean()
print("Частка пропусків")
print(res2)
# Out:
# Частка пропусків
# Мова програмування                  0.442325
# N                                   0.000000
# Посада                              0.000000
# Загальний досвід роботи             0.000000
# Досвід роботи на поточному місці    0.000000
# Зарплата на місяць                  0.000000
# Зміна зарплати за 12 місяців        0.000000
# Місто                               0.000000
# Розмір компанії                     0.000000
# Тип компанії                        0.000000
# Стать                               0.000000
# Вік                                 0.000000
# Освіта                              0.000000
# Ще студент                          0.000000
# Рівень англійської                  0.000000
# Дата заповнення                     0.000000
# User.Agent                          0.000000
# exp                                 0.000000
# current_job_exp                     0.000000
# salary                              0.000000
# dtype: float64

# %% [markdown]
# - Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
coders.dropna(inplace=True)
coders
# Out:
#      Мова програмування     N                    Посада  \
# 2               C#/.NET     3         Software Engineer
# 3            JavaScript     4         Software Engineer
# 4            JavaScript     5  Senior Software Engineer
# 6               C#/.NET     7  Junior Software Engineer
# 7                   C++     8  Senior Software Engineer
# ...                 ...   ...                       ...
# 8692               Java  8693         Software Engineer
# 8694            C#/.NET  8695  Junior Software Engineer
# 8695             Python  8696         Software Engineer
# 8701         Ruby/Rails  8702  Junior Software Engineer
# 8703               Java  8704  Senior Software Engineer
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 2                          4                                1
# 3                          5                                4
# 4          10 і більше років                              0.5
# ...

# %% [markdown]
# - Визначте новий розмір таблиці за допомогою методу shape

# %%
coders.shape
# Out:
# (4854, 20)

# %% [markdown]
# - Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = coders[coders['Мова програмування'] == 'Python']
python_data
# Out:
#      Мова програмування     N                    Посада  \
# 12               Python    13         Software Engineer
# 68               Python    69         Software Engineer
# 87               Python    88  Junior Software Engineer
# 114              Python   115  Junior Software Engineer
# 143              Python   144  Junior Software Engineer
# ...                 ...   ...                       ...
# 8546             Python  8547         Software Engineer
# 8625             Python  8626         Software Engineer
# 8635             Python  8636  Senior Software Engineer
# 8673             Python  8674  Junior Software Engineer
# 8695             Python  8696         Software Engineer
#
#      Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                         1                  менше 3 місяців
# 68                       1.5                              0.5
# 87                       0.5                              0.5
# ...

# %% [markdown]
# - Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# - Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
grouped_data = python_data.groupby('Посада')

# %% [markdown]
# -Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
salaries = grouped_data['Зарплата на місяць'].agg(['min', 'max'])

salaries
# Out:
#                            min   max
# Посада
# Junior Software Engineer   100  1250
# Senior Software Engineer  1300  9200
# Software Engineer          500  5400
# System Architect          3000  5000
# Technical Lead            1425  6200

# %% [markdown]
# - Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(row):
    return row.mean()

salaries['avg'] = salaries.apply(fill_avg_salary, axis=1)

# %% [markdown]
# - Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
salaries["avg"].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %% [markdown]
# Збережіть отриману таблицю в CSV файл

# %%
salaries.to_csv('/content/python_salaries.csv')
salaries
# Out:
#                            min   max     avg
# Посада
# Junior Software Engineer   100  1250   675.0
# Senior Software Engineer  1300  9200  5250.0
# Software Engineer          500  5400  2950.0
# System Architect          3000  5000  4000.0
# Technical Lead            1425  6200  3812.5

# %%
salaries2 = pd.read_csv('/content/python_salaries.csv')
salaries2
# Out:
#                      Посада   min   max     avg
# 0  Junior Software Engineer   100  1250   675.0
# 1  Senior Software Engineer  1300  9200  5250.0
# 2         Software Engineer   500  5400  2950.0
# 3          System Architect  3000  5000  4000.0
# 4            Technical Lead  1425  6200  3812.5

# %% [markdown]
# Додайте від 3 до 5 графіків функцій різного типу на ваш вибір. Задайте графікам оформлення, щоб кожен графік у своїй домашній роботі чимось відрізнявся і не був схожим на інші. Можна використовувати як matplotlib, так і seaborn.

# %%
coders.head()
# Out:
#   Мова програмування  N                    Посада Загальний досвід роботи  \
# 2            C#/.NET  3         Software Engineer                       4
# 3         JavaScript  4         Software Engineer                       5
# 4         JavaScript  5  Senior Software Engineer       10 і більше років
# 6            C#/.NET  7  Junior Software Engineer                       1
# 7                C++  8  Senior Software Engineer                       6
#
#   Досвід роботи на поточному місці  Зарплата на місяць  \
# 2                                1                2500
# 3                                4                2000
# 4                              0.5                4500
# 6                  менше 3 місяців                 600
# 7                                1                3300
#
#    Зміна зарплати за 12 місяців         Місто Розмір компанії   Тип компанії  \
# 2                           800          Київ    до 1000 осіб  Аутсорсингова
# ...

# %%
import seaborn as sns

sns.set_style("darkgrid")
sns.boxenplot(data=coders, y="Посада", x="Зарплата на місяць").set(title='Залежність заробітної плати від посади')
# Out:
# [Text(0.5, 1.0, 'Залежність заробітної плати від посади')]

# %%
python_data.head()
# Out:
#     Мова програмування    N                    Посада Загальний досвід роботи  \
# 12              Python   13         Software Engineer                       1
# 68              Python   69         Software Engineer                     1.5
# 87              Python   88  Junior Software Engineer                     0.5
# 114             Python  115  Junior Software Engineer                     1.5
# 143             Python  144  Junior Software Engineer                       1
#
#     Досвід роботи на поточному місці  Зарплата на місяць  \
# 12                   менше 3 місяців                 800
# 68                               0.5                 900
# 87                               0.5                 600
# 114                              0.5                 685
# 143                                1                 750
#
#      Зміна зарплати за 12 місяців Місто Розмір компанії   Тип компанії  \
# 12                            200  Київ      до 50 осіб  Аутсорсингова
# ...

# %%
import seaborn as sns

sns.relplot(data=python_data, y="Місто", x="Зарплата на місяць", hue="Загальний досвід роботи").set(title='Залежність заробітної плати від міста та досвіду')

# %%
salaries2.head()
# Out:
#                      Посада   min   max     avg
# 0  Junior Software Engineer   100  1250   675.0
# 1  Senior Software Engineer  1300  9200  5250.0
# 2         Software Engineer   500  5400  2950.0
# 3          System Architect  3000  5000  4000.0
# 4            Technical Lead  1425  6200  3812.5

# %%
import seaborn as sns

sns.set_style("whitegrid")
sns.violinplot(data=salaries2).set(title='Коливання заробітних плат')
# Out:
# [Text(0.5, 1.0, 'Коливання заробітних плат')]
